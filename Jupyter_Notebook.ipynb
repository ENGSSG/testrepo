# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Hyunseok Kim**
#
# Management Consultant

# %% [markdown]
# *I was intorduced to data science by my finance friend. Ever since then I was interested how it solved the real life problems. After using some data to gain insight on my final year project, I knew this was the path for me. I never thought I enjoyed studying until that moment.*

# %% [markdown]
# ### The below code just plots a simple linear line

# %%
import matplotlib.pyplot as plt

x=(0, 1, 2, 3, 4, 5);
y=(0, 1, 2, 3, 4, 5);
plt.plot(x,y);
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Tables | Contents
# --- | :---:
#  Linkedin | [My LinkedIn Profile](https://www.linkedin.com/in/hyunseok-kim-99356912a/)
#  CV | ~~My CV~~
